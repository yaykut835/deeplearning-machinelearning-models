# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("mushroom.csv")
df.head(3)
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0            y          w         u          w        t         g
# 1            y          w         u          w        t         g
# 2            y          w         u          w        t         g
#
#   spore-print-color habitat season
# 0               NaN       d      w
# 1               NaN       d      u
# ...

# %%
df=df.dropna(subset=["gill-spacing", "spore-print-color"])

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head(3)
# Out:
#        cap-diameter  stem-height  stem-width  class_p  cap-shape_f  \
# 14826         12.33         9.21       18.23    False        False
# 14827          9.55        10.59       15.88    False        False
# 14828          8.61        10.42       15.13    False        False
#
#        cap-shape_o  cap-shape_s  cap-shape_x  cap-surface_i  cap-surface_l  \
# 14826        False        False         True          False          False
# 14827        False        False         True          False          False
# 14828        False        False         True          False          False
#
#        ...  spore-print-color_p  spore-print-color_r  spore-print-color_u  \
# 14826  ...                False                False                False
# 14827  ...                False                False                False
# 14828  ...                False                False                False
#
#        spore-print-color_w  habitat_g  habitat_l  habitat_m  season_s  \
# ...

# %%
y=df["class_p"].values
x=df.drop("class_p", axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.75, random_state=78)

# %%
model=Sequential()

model.add(Dense(32, input_dim=55, activation="relu"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(Dense(32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x=x, y=y, epochs=16, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/16
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_88
# Received: inputs=('Tensor(shape=(None, 55))',)
#   warnings.warn(msg)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 1.0000 - loss: 6.0281e-10 - val_accuracy: 0.4450 - val_loss: 5.3071
# Epoch 2/16
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_88
# Received: inputs=('Tensor(shape=(None, 55))',)
#   warnings.warn(msg)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.2586e-10 - val_accuracy: 0.4450 - val_loss: 5.3104
# Epoch 3/16
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.4226e-10 - val_accuracy: 0.4450 - val_loss: 5.3128
# Epoch 4/16
# ...

# %%
train_score = model.evaluate(x_train, y_train, verbose=0)
test_score = model.evaluate(x_test, y_test, verbose=0)

# %%
test_score
# Out:
# [1.0185697078704834, 0.8955974578857422]
